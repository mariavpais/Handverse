# %%
import sklearn
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier

# %%
dataframe_features = pd.read_csv("./landmarks_hv")

# %%
dataframe_features.drop("Unnamed: 0",axis=1,inplace=True)

# %%
X = dataframe_features.drop("label",axis=1)

# %%
X
# Out:
#         x0   x1   x2   x3   x4   x5   x6  x7   x8  x9  ...  y11  y12  y13  \
# 0       90  133  113  105  127   79  129  56  126  37  ...   93   92   63
# 1       96  128  121  109  135   83  137  60  135  42  ...  102  101   72
# 2      112  154  142  140  159  108  161  78  161  55  ...  113  136   80
# 3      139  145  155  124  165  105  171  87  171  73  ...  139  112  124
# 4      144  143  166  128  179   97  178  72  175  52  ...  141  123  107
# ...    ...  ...  ...  ...  ...  ...  ...  ..  ...  ..  ...  ...  ...  ...
# 70359   94  152  118  144  136  119  124  91  108  79  ...  106  110   97
# 70360   96  151  117  146  135  120  125  91  109  79  ...  106  110   98
# 70361   96  149  118  145  136  120  125  91  107  79  ...  108  109   97
# 70362   94  151  117  144  136  119  124  91  107  79  ...  106  109   96
# 70363   93  149  115  145  134  119  124  89  106  77  ...  106  109   97
#
#        y14  y15  y16  y17  y18  y19  y20
# 0       67   75   63   79   78   80   89
# 1       69   85   72   89   89   89   99
# 2      100   88   92   93  117   96  132
# 3       98  124   90  127  100  129  110
# 4       97  119   89  125  109  127  123
# ...    ...  ...  ...  ...  ...  ...  ...
# 70359   91   93   75   92   93   92  107
# 70360   90   93   74   92   93   91  106
# 70361   89   94   75   92   92   92  105
# 70362   90   92   75   91   93   91  107
# 70363   88   92   73   90   91   90  105
#
# [70364 rows x 42 columns]

# %%
Y = dataframe_features["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=1)

# %%
l = LabelEncoder()
y = l.fit_transform(y_train)

# %%
model = GradientBoostingClassifier()

# %%
model.fit(X_train, y)

# %%
y_p = l.fit_transform(y_test)

# %%
y_pred = model.predict(X_test)

# %%
accuracy_score(y_p,y_pred)
# Out:
# 0.988346479073403

# %%
model.save_model("modelxgboost.json")
